# %% [markdown]
# ## Want to run a set of tiles with network flow method, and the output can be compared with the one from the greedy method. --09-03-2026

# %%
import argparse
import glob
import gc
import os
import signal
import sys
import time
from collections import defaultdict

import healpy as hp
import numpy as np
from astropy.table import Table
from numpy.random import Generator, PCG64

#sys.path.append("/home/zjding/installed_packages/JUST_fiberassign/py/")
sys.path.append("/home/zjding/installed_packages/code_dev/JUST_fiberassign/JUST_fiberassign/")  # --08-26-2026

# %%
from parameters import (
    COLLISION_SEPARATION_ARCSEC,
    COLLISION_SEPARATION_DEG,
    COLLISION_SEPARATION_MM,
    TILE_OUTER_RADIUS_DEG,
    R_PATROL_DEG,
)
from utils import _log, get_fiberpos, write_fba_onetile, find_neighboring_fibers
from fba_single_tile import (
    _degrade_mtl_priorities_on_disk,
    _fits_path_for_tile,
    _healpix_ids_for_disc,
    fba_onetile_decollided,
    fba_onetile,
    load_galaxies_from_mtlpix,
    FBASolveFailed,
)

# %%
DECOLLIDED_TIMEOUT_SEC = 100.0
FALLBACK_TIMEOUT_SEC = 180.0   # change this according to the number of iterations

# %%
class FBAOnetileTimeout(TimeoutError):
    """Raised when fba_onetile_decollided exceeds the per-tile time limit."""

def _run_with_timeout(timeout_sec, func, *args, **kwargs):
    if timeout_sec is None or timeout_sec <= 0:
        return func(*args, **kwargs)

    previous_handler = signal.getsignal(signal.SIGALRM)

    def _handler(signum, frame):
        raise FBAOnetileTimeout(
            f"{func.__name__} exceeded {timeout_sec:.0f}s"
        )

    signal.signal(signal.SIGALRM, _handler)
    signal.setitimer(signal.ITIMER_REAL, float(timeout_sec))
    try:
        return func(*args, **kwargs)
    finally:
        signal.setitimer(signal.ITIMER_REAL, 0.0)
        signal.signal(signal.SIGALRM, previous_handler)


def _decollided_fail_path(out_dir):
    return os.path.join(out_dir, "fba_decollided_timeout_tiles.txt")


def _skipped_tiles_path(out_dir):
    return os.path.join(out_dir, "fba_skipped_tiles.txt")


def _tile_ids_from_file(path):
    if not os.path.isfile(path):
        return set()
    with open(path, encoding="utf-8") as f:
        return {int(line.strip()) for line in f if line.strip()}


def _append_tile_id(tile_id, path):
    """Append one TILEID per line to a persistent tile list."""
    with open(path, "a", encoding="utf-8") as f:
        f.write(f"{int(tile_id)}\n")
        f.flush()
        os.fsync(f.fileno())


def _record_decollided_fail(tile_id, fail_path):
    """Append a TILEID that timed out in fba_onetile_decollided."""
    _append_tile_id(tile_id, fail_path)


def _fba_onetile_decollided_or_fallback(
    tile_ra,
    tile_dec,
    tile_id,
    gal_mtl,
    neighboring_fiber_pairs,
    fiberpos_xy,
    eval_workers,
    decollided_fail_path,
    skipped_tiles_path,
    decollided_timeout_sec=DECOLLIDED_TIMEOUT_SEC,
    fallback_timeout_sec=FALLBACK_TIMEOUT_SEC,
):
    """Try fba_onetile_decollided; on timeout or solve failure fall back to fba_onetile."""
    t0 = time.time()
    try:
        result = _run_with_timeout(
            decollided_timeout_sec,
            fba_onetile_decollided,
            tile_ra,
            tile_dec,
            tile_id,
            gal_mtl,
            neighboring_fiber_pairs,
            fiberpos_xy,
            eval_workers,
        )
        if result is None:
            _log(f"  Tile {tile_id}: no assignable targets; skipping")
            return None
        _log(
            f"  fba_onetile_decollided finished in {time.time() - t0:.2f}s"
        )
        return result
    except (FBAOnetileTimeout, FBASolveFailed) as exc:
        elapsed = time.time() - t0
        _record_decollided_fail(tile_id, decollided_fail_path)
        _log(
            f"  Tile {tile_id}: {exc} (elapsed {elapsed:.1f}s); "
            f"falling back to fba_onetile (recorded in {decollided_fail_path})"
        )
        t1 = time.time()
        try:
            result = _run_with_timeout(
                fallback_timeout_sec,
                fba_onetile,
                tile_ra,
                tile_dec,
                tile_id,
                gal_mtl,
                neighboring_fiber_pairs,
                fiberpos_xy,
                eval_workers,
            )
            _log(f"  fba_onetile finished in {time.time() - t1:.2f}s")
            return result
        except Exception as fallback_exc:
            _append_tile_id(tile_id, skipped_tiles_path)
            _log(
                f"  Tile {tile_id}: fba_onetile failed ({fallback_exc}); "
                f"skipping assignment (recorded in {skipped_tiles_path})"
            )
            return None

def _list_completed_tiles(out_dir):
    completed = set()
    for path in glob.glob(os.path.join(out_dir, "fba_tile_*.fits")):
        base = os.path.basename(path)
        try:
            completed.add(int(base[len("fba_tile_") : -len(".fits")]))
        except ValueError:
            continue
    return completed

# %%
input_mockpath="/home/zjding/fiberassignment/JUST/BGS_mock/Junyu_mock/galaxy_cluster/input/lightcone_ra_0_90_dec_0_90_rmagcut20.5_cluster_mask.fits"
input_tilepath="/home/zjding/fiberassignment/JUST/BGS_mock/Junyu_mock/galaxy_cluster/input/tiles_optimized_pass1_2_v0.8.fits"
output_fba_path="./fba/nwf/decollided/"
mock_version="v1"
Npasses = 3
ra0=0
ra1=90
dec0=0
dec1=90
n_workers = 2
eval_workers = 1
max_iterations = 1
rand_seed = 100
no_resume = False
nside = 32
# set target priority
priority_initial = 100.0
priority_degraded = 2.0

# %%
pool_workers = max(1, n_workers - 2) if n_workers > 2 else n_workers

os.environ.setdefault("OMP_NUM_THREADS", "1")
os.environ.setdefault("OPENBLAS_NUM_THREADS", "1")
os.environ.setdefault("MKL_NUM_THREADS", "1")
os.environ.setdefault("NUMEXPR_NUM_THREADS", "1")

rng = Generator(PCG64(seed=rand_seed))
_log(
    f"rand_seed={rand_seed}, pool_workers={pool_workers}, "
    f"eval_workers={eval_workers}, max_iterations={max_iterations}"
)
_log(f"Patrol radius: {R_PATROL_DEG:.6f} degrees")
_log(
    f"Collision separation: {COLLISION_SEPARATION_ARCSEC} arcsec = "
    f"{COLLISION_SEPARATION_DEG:.6f} deg = {COLLISION_SEPARATION_MM:.3f} mm"
)

fiberpos_xy = get_fiberpos()
N_fibers = fiberpos_xy.shape[0]
_log(f"Number of fibers: {N_fibers}")


input_cat = Table.read(input_mockpath)
mask = (
    (input_cat["ra"] > ra0)
    & (input_cat["ra"] < ra1)
    & (input_cat["dec"] > dec0)
    & (input_cat["dec"] < dec1)
)
input_cat = input_cat[mask]

gal_MTL = Table()

columns = ["TARGETID", "RA", "DEC", "PRIORITY", "SUBPRIORITY"]
for col in columns:
    if col == "TARGETID":
        gal_MTL[col] = input_cat["idx"]
    elif col == "RA":
        gal_MTL[col] = input_cat["ra"]
    elif col == "DEC":
        gal_MTL[col] = input_cat["dec"]
    elif col == "PRIORITY":
        gal_MTL[col] = np.ones(len(input_cat), dtype=float) * priority_initial
        mask = (input_cat["cluster_mask"] == 0)  # distinguish between inside/outside the galaxy cluster center mask
        gal_MTL["PRIORITY"][mask] = priority_degraded
    elif col == "SUBPRIORITY":
        gal_MTL[col] = rng.random(len(input_cat))
    else:
        gal_MTL[col] = input_cat[col]
        
del input_cat
gc.collect()
# Out:
# rand_seed=100, pool_workers=2, eval_workers=1, max_iterations=1
# Patrol radius: 0.013021 degrees
# Collision separation: 15.625 arcsec = 0.004340 deg = 2.000 mm
# Number of fibers: 2184
# 272

# %%
tiles_sub = Table.read(input_tilepath)
##N_tiles = len(tiles_sub)
N_tiles = 11987
# add PASS column to the tiles_sub
tiles_sub["PASS"] = np.array(tiles_sub["TILEID"]//100_000 - 1, dtype=np.int64)

neighboring_fiber_pairs = find_neighboring_fibers(
    fiberpos_xy, patrol_center_separation=12.0
)
_log(f"There are {len(neighboring_fiber_pairs)} paired fibers in one tile")

out_dir = (
    output_fba_path
    + f"/{N_tiles}tiles_{ra0:.1f}ra{ra1:.1f}_{dec0:.1f}dec{dec1:.1f}/seed{rand_seed}/"
)
os.makedirs(out_dir, exist_ok=True)
decollided_fail_path = _decollided_fail_path(out_dir)
skipped_tiles_path = _skipped_tiles_path(out_dir)
# Out:
# There are 6312 paired fibers in one tile

# %%
if no_resume:
    for path in (decollided_fail_path, skipped_tiles_path):
        if os.path.isfile(path):
            os.remove(path)
_log(f"Decollided timeout tile list: {decollided_fail_path}")
_log(f"Skipped tile list: {skipped_tiles_path}")
skipped_tiles = _tile_ids_from_file(skipped_tiles_path)
if skipped_tiles:
    _log(f"Resume: will skip {len(skipped_tiles)} previously failed tile(s)")

nest = False
mtl_dir = out_dir + f"/mtl_nside{nside}/"
mtl_files_exist = bool(glob.glob(os.path.join(mtl_dir, "mtl_healpix_*.fits")))
if no_resume or not mtl_files_exist:
    _log("Split the MTL galaxies into pixels for a fresh fiber-assignment run.")
    npix = hp.nside2npix(nside)
    pix_area_deg2 = hp.nside2pixarea(nside, degrees=True)
    _log(
        f"HEALPix nside={nside}: {npix} pixels, "
        f"~{np.sqrt(pix_area_deg2):.2f} deg/pixel side"
    )

    ra = np.asarray(gal_MTL["RA"], dtype=np.float64)
    dec = np.asarray(gal_MTL["DEC"], dtype=np.float64)
    pix = hp.ang2pix(nside, ra, dec, lonlat=True, nest=nest)

    gal_MTL["HEALPIXID"] = pix.astype(np.int64)
    _log(f"Assigned {len(gal_MTL)} galaxies to {len(np.unique(pix))} non-empty pixels")

    sort_idx = np.argsort(pix, kind="stable")
    pix_sorted = pix[sort_idx]
    unique_pix, start_idx, counts = np.unique(
        pix_sorted, return_index=True, return_counts=True
    )

    pixel_cats = {}
    for pix_id, start, count in zip(unique_pix, start_idx, counts):
        rows = sort_idx[start : start + count]
        pixel_cats[int(pix_id)] = gal_MTL[rows]

    _log(f"Built pixel_cats with {len(pixel_cats)} entries")
    _log(
        "Galaxies per pixel: "
        f"min={counts.min()}, median={np.median(counts):.0f}, max={counts.max()}"
    )

    os.makedirs(mtl_dir, exist_ok=True)
    for pix_id, cat_pix in pixel_cats.items():
        ofile = os.path.join(mtl_dir, f"mtl_healpix_{pix_id:05d}.fits")
        cat_pix.write(ofile, overwrite=True)
    _log(f"Wrote {len(pixel_cats)} pixel catalogs to {mtl_dir}")

    del gal_MTL, pixel_cats
    gc.collect()
else:
    _log(f"Resume: reusing existing MTL pixel files in {mtl_dir}")
    del gal_MTL
    gc.collect()

if no_resume:
    completed_tiles = set()
    _log("Resume disabled (--no_resume); starting from scratch")
else:
    completed_tiles = _list_completed_tiles(out_dir)
    if completed_tiles:
        _log(f"Resume: found {len(completed_tiles)} completed tile(s) in {out_dir}")
    else:
        _log(f"Resume: no completed tiles found in {out_dir}")

near_radius_deg = 1.2 * TILE_OUTER_RADIUS_DEG
_log(
    f"Load the sample from healpixID files, where some galaxies are within "
    f"{near_radius_deg:.6f} deg of the tile center."
)
# Out:
# Decollided timeout tile list: ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_decollided_timeout_tiles.txt
# Skipped tile list: ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_skipped_tiles.txt
# Split the MTL galaxies into pixels for a fresh fiber-assignment run.
# HEALPix nside=32: 12288 pixels, ~1.83 deg/pixel side
# Assigned 13032492 galaxies to 1568 non-empty pixels
# Built pixel_cats with 1568 entries
# Galaxies per pixel: min=3418, median=8422, max=10830
# Wrote 1568 pixel catalogs to ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100//mtl_nside32/
# Resume: no completed tiles found in ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/
# Load the sample from healpixID files, where some galaxies are within 0.716160 deg of the tile center.

# %%
#for passid in range(Npasses):
passid = 1

Ntiles = 20  # number of tiles to run

t0 = time.time()
_log(f"passid: {passid}")
mask = (tiles_sub["PASS"] == passid)
tiles_ra_pass = np.asarray(tiles_sub["RA_NEW"][mask], dtype=np.float64)
tiles_dec_pass = np.asarray(tiles_sub["DEC_NEW"][mask], dtype=np.float64)
tiles_id_pass = np.asarray(tiles_sub["TILEID"][mask], dtype=np.int64)
_log(f"Number of tiles in pass {passid}: {len(tiles_ra_pass)}")

for tile_ra, tile_dec, tile_id in zip(
    tiles_ra_pass[0:Ntiles], tiles_dec_pass[0:Ntiles], tiles_id_pass[0:Ntiles]
):
    out_fits = _fits_path_for_tile(out_dir, tile_id)
    if not no_resume and tile_id in completed_tiles:
        _log(f"Tile {tile_id}: skip (already exists) {out_fits}")
        continue
    if not no_resume and tile_id in skipped_tiles:
        _log(
            f"Tile {tile_id}: skip (assignment previously failed; "
            f"see {skipped_tiles_path})"
        )
        continue

    pix_ids = _healpix_ids_for_disc(
        tile_ra, tile_dec, near_radius_deg, nside, nest=nest
    )
    gal_mtl = load_galaxies_from_mtlpix(
        tile_ra,
        tile_dec,
        mtl_dir,
        near_radius_deg,
        nside=nside,
        nest=nest,
    )
    _log(
        f"Tile {tile_id} ({tile_ra:.4f}, {tile_dec:.4f}): "
        f"loaded {len(gal_mtl)} galaxies from {len(pix_ids)} HEALPix file(s) "
        f"pix={pix_ids.tolist()}"
    )

    t_fba_start = time.time()
    fba_out = _fba_onetile_decollided_or_fallback(
        tile_ra,
        tile_dec,
        tile_id,
        gal_mtl,
        neighboring_fiber_pairs,
        fiberpos_xy,
        eval_workers,
        decollided_fail_path,
        skipped_tiles_path,
    )
    t_fba_end = time.time()
    _log(f"  fba total time: {t_fba_end - t_fba_start:.2f}s")
    if fba_out is None:
        skipped_tiles.add(int(tile_id))
        _log(f"Tile {tile_id}: assignment skipped\n")
        _log("=====================")
        continue

    fba_result, targets_id_list_alltiles = fba_out

    per_tile_assigned = defaultdict(lambda: {"target_ids": [], "fiber_ids": []})
    for _tid, _node in fba_result["target_to_fiber"].items():
        _node = str(_node)
        if "_fiber_" not in _node:
            continue
        _tile, _fid = _node.rsplit("_fiber_", 1)
        try:
            _fid = int(_fid)
        except Exception:
            continue
        per_tile_assigned[_tile]["target_ids"].append(int(_tid))
        per_tile_assigned[_tile]["fiber_ids"].append(_fid)

    assigned_tarids_all = []
    for _tile, _vals in per_tile_assigned.items():
        assigned_targets_id = _vals["target_ids"]
        assigned_tarids_all.extend(assigned_targets_id)
        write_fba_onetile(
            tile_id=_tile,
            assigned_targets_id=assigned_targets_id,
            assigned_fiber_id=_vals["fiber_ids"],
            targets_id_list_alltiles=targets_id_list_alltiles,
            out_fits_path=out_fits,
            overwrite=True,
        )
    t_outfits_end = time.time()
    _log(
        f"  Wrote {out_fits} ({len(assigned_targets_id)} assignments); "
        f"takes {t_outfits_end - t_fba_end:.2f}s"
    )

    if assigned_tarids_all:
        affected_pix = np.unique(
            gal_mtl["HEALPIXID"][
                np.isin(gal_mtl["TARGETID"], assigned_tarids_all)
            ]
        )
        n_disk = _degrade_mtl_priorities_on_disk(
            mtl_dir, assigned_tarids_all, priority_degraded, affected_pix
        )
        _log(
            f"  Updated PRIORITY on disk for {n_disk} row(s) "
            f"in {len(affected_pix)} pixel file(s): {affected_pix.tolist()}"
        )
    completed_tiles.add(int(tile_id))
    _log(f"  Update the MTL PRIORITY files in {time.time() - t_outfits_end:.2f}s\n")
    _log("=====================")

_log(f"pass {passid} running time (s): {time.time() - t0:.1f}")

if os.path.isfile(decollided_fail_path):
    n_fail = len(_tile_ids_from_file(decollided_fail_path))
    _log(f"Total tiles that timed out in fba_onetile_decollided: {n_fail} ({decollided_fail_path})")
if os.path.isfile(skipped_tiles_path):
    n_skipped = len(_tile_ids_from_file(skipped_tiles_path))
    _log(f"Total tiles skipped after fallback failure: {n_skipped} ({skipped_tiles_path})")
# Out:
# passid: 1
# Number of tiles in pass 1: 3996
# Tile 208445 (65.4608, 86.6870): loaded 25300 galaxies from 3 HEALPix file(s) pix=[5, 13, 14]
#   Tile 208445: priority-weighted collision-free subset 2765/3165 targets (sep > 15.625 arcsec, sum priority+subpriority=277927.2)
#   Tile 208445: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=8916382307.00, assigned=1594, used_fibers=1594/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.76s
#   fba total time: 1.76s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208445.fits (1594 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1594 row(s) in 2 pixel file(s): [5, 14]
#   Update the MTL PRIORITY files in 0.03s
#
# =====================
# Tile 208748 (86.5695, 87.5306): loaded 25930 galaxies from 6 HEALPix file(s) pix=[0, 1, 5, 6, 14, 15]
#   Tile 208748: priority-weighted collision-free subset 1450/1628 targets (sep > 15.625 arcsec, sum priority+subpriority=145765.4)
#   Tile 208748: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=4173604688.00, assigned=905, used_fibers=905/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 0.72s
#   fba total time: 0.72s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208748.fits (905 assignments); takes 0.01s
#   Updated PRIORITY on disk for 905 row(s) in 2 pixel file(s): [5, 14]
#   Update the MTL PRIORITY files in 0.02s
#
# =====================
# Tile 208540 (45.6933, 83.7342): loaded 32180 galaxies from 4 HEALPix file(s) pix=[13, 25, 26, 42]
#   Tile 208540: priority-weighted collision-free subset 2172/2382 targets (sep > 15.625 arcsec, sum priority+subpriority=14266.3)
#   Tile 208540: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=6531638745.00, assigned=1363, used_fibers=1363/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 0.91s
#   fba total time: 0.91s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208540.fits (1363 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1363 row(s) in 4 pixel file(s): [13, 25, 26, 42]
#   Update the MTL PRIORITY files in 0.05s
#
# =====================
# Tile 208449 (53.8471, 85.6818): loaded 33552 galaxies from 4 HEALPix file(s) pix=[5, 13, 14, 26]
#   Tile 208449: priority-weighted collision-free subset 2394/2663 targets (sep > 15.625 arcsec, sum priority+subpriority=165293.6)
#   Tile 208449: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=6966249493.00, assigned=1450, used_fibers=1450/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.92s
#   fba total time: 1.92s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208449.fits (1450 assignments); takes 0.02s
#   Updated PRIORITY on disk for 1450 row(s) in 4 pixel file(s): [5, 13, 14, 26]
#   Update the MTL PRIORITY files in 0.06s
#
# =====================
# Tile 208453 (29.6644, 86.7597): loaded 42079 galaxies from 5 HEALPix file(s) pix=[0, 4, 5, 12, 13]
#   Tile 208453: priority-weighted collision-free subset 2334/2579 targets (sep > 15.625 arcsec, sum priority+subpriority=205883.6)
#   Tile 208453: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=7020048847.00, assigned=1383, used_fibers=1383/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.54s
#   fba total time: 1.54s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208453.fits (1383 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1383 row(s) in 2 pixel file(s): [4, 13]
#   Update the MTL PRIORITY files in 0.03s
#
# =====================
# Tile 208749 (56.0928, 88.6742): loaded 17703 galaxies from 3 HEALPix file(s) pix=[0, 1, 5]
#   Tile 208749: priority-weighted collision-free subset 2279/2551 targets (sep > 15.625 arcsec, sum priority+subpriority=229061.0)
#   Tile 208749: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=6375699545.00, assigned=1381, used_fibers=1381/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.01s
#   fba total time: 1.01s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208749.fits (1381 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1381 row(s) in 1 pixel file(s): [0]
#   Update the MTL PRIORITY files in 0.02s
#
# =====================
# Tile 208750 (15.8228, 88.6527): loaded 16558 galaxies from 4 HEALPix file(s) pix=[0, 3, 4, 11]
#   Tile 208750: priority-weighted collision-free subset 1979/2183 targets (sep > 15.625 arcsec, sum priority+subpriority=185872.0)
#   Tile 208750: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=5793411941.00, assigned=1221, used_fibers=1221/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 0.94s
#   fba total time: 0.94s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208750.fits (1221 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1221 row(s) in 2 pixel file(s): [0, 4]
#   Update the MTL PRIORITY files in 0.03s
#
# =====================
# Tile 208751 (23.6354, 88.9156): loaded 16558 galaxies from 4 HEALPix file(s) pix=[0, 3, 4, 11]
#   Tile 208751: priority-weighted collision-free subset 2089/2314 targets (sep > 15.625 arcsec, sum priority+subpriority=102532.3)
#   Tile 208751: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=6438550018.00, assigned=1297, used_fibers=1297/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 0.97s
#   fba total time: 0.97s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208751.fits (1297 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1297 row(s) in 1 pixel file(s): [0]
#   Update the MTL PRIORITY files in 0.01s
#
# =====================
# Tile 208451 (37.7149, 87.5628): loaded 33631 galaxies from 4 HEALPix file(s) pix=[0, 4, 5, 13]
#   Tile 208451: priority-weighted collision-free subset 2515/2810 targets (sep > 15.625 arcsec, sum priority+subpriority=201933.3)
#   Tile 208451: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=8124736859.00, assigned=1488, used_fibers=1488/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.32s
#   fba total time: 1.32s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208451.fits (1488 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1488 row(s) in 3 pixel file(s): [0, 4, 5]
#   Update the MTL PRIORITY files in 0.04s
#
# =====================
# Tile 208452 (14.2119, 87.2443): loaded 25006 galaxies from 5 HEALPix file(s) pix=[0, 4, 11, 12, 23]
#   Tile 208452: priority-weighted collision-free subset 2449/2762 targets (sep > 15.625 arcsec, sum priority+subpriority=100915.0)
#   Tile 208452: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=7684069895.00, assigned=1449, used_fibers=1449/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 2.03s
#   fba total time: 2.03s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208452.fits (1449 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1449 row(s) in 2 pixel file(s): [4, 12]
#   Update the MTL PRIORITY files in 0.03s
#
# =====================
# Tile 208448 (48.2370, 86.7823): loaded 33631 galaxies from 4 HEALPix file(s) pix=[0, 4, 5, 13]
#   Tile 208448: priority-weighted collision-free subset 2883/3301 targets (sep > 15.625 arcsec, sum priority+subpriority=252929.9)
#   Tile 208448: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=10097089670.00, assigned=1606, used_fibers=1606/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.50s
#   fba total time: 1.50s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208448.fits (1606 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1606 row(s) in 4 pixel file(s): [0, 4, 5, 13]
#   Update the MTL PRIORITY files in 0.05s
#
# =====================
# Tile 208747 (62.8048, 87.1730): loaded 41858 galaxies from 5 HEALPix file(s) pix=[0, 4, 5, 13, 14]
#   Tile 208747: priority-weighted collision-free subset 2977/3454 targets (sep > 15.625 arcsec, sum priority+subpriority=217586.1)
#   Tile 208747: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=10817437672.00, assigned=1636, used_fibers=1636/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.50s
#   fba total time: 1.50s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208747.fits (1636 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1636 row(s) in 1 pixel file(s): [5]
#   Update the MTL PRIORITY files in 0.02s
#
# =====================
# Tile 208768 (39.2736, 85.2860): loaded 32107 galaxies from 4 HEALPix file(s) pix=[4, 12, 13, 25]
#   Tile 208768: priority-weighted collision-free subset 2060/2273 targets (sep > 15.625 arcsec, sum priority+subpriority=5198.3)
#   Tile 208768: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=5736798258.00, assigned=1309, used_fibers=1309/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.02s
#   fba total time: 1.02s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208768.fits (1309 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1309 row(s) in 2 pixel file(s): [13, 25]
#   Update the MTL PRIORITY files in 0.03s
#
# =====================
# Tile 208402 (25.3390, 84.8692): loaded 49319 galaxies from 6 HEALPix file(s) pix=[4, 12, 13, 24, 25, 41]
#   Tile 208402: priority-weighted collision-free subset 2383/2630 targets (sep > 15.625 arcsec, sum priority+subpriority=128112.8)
#   Tile 208402: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=7286631178.00, assigned=1439, used_fibers=1439/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.86s
#   fba total time: 1.86s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208402.fits (1439 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1439 row(s) in 2 pixel file(s): [12, 25]
#   Update the MTL PRIORITY files in 0.03s
#
# =====================
# Tile 208382 (28.6462, 80.9259): loaded 35125 galaxies from 4 HEALPix file(s) pix=[41, 61, 62, 86]
#   Tile 208382: priority-weighted collision-free subset 2405/2683 targets (sep > 15.625 arcsec, sum priority+subpriority=233476.3)
#   Tile 208382: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=7005261119.00, assigned=1455, used_fibers=1455/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.20s
#   fba total time: 1.20s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208382.fits (1455 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1455 row(s) in 4 pixel file(s): [41, 61, 62, 86]
#   Update the MTL PRIORITY files in 0.05s
#
# =====================
# Tile 208471 (6.9886, 84.3302): loaded 25589 galaxies from 5 HEALPix file(s) pix=[12, 24, 39, 40, 59]
#   Tile 208471: priority-weighted collision-free subset 2724/3093 targets (sep > 15.625 arcsec, sum priority+subpriority=168737.6)
#   Tile 208471: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=8584297643.00, assigned=1560, used_fibers=1560/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.87s
#   fba total time: 1.87s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208471.fits (1560 assignments); takes 0.02s
#   Updated PRIORITY on disk for 1560 row(s) in 2 pixel file(s): [24, 40]
#   Update the MTL PRIORITY files in 0.04s
#
# =====================
# Tile 208407 (5.4489, 85.5204): loaded 17217 galaxies from 4 HEALPix file(s) pix=[12, 23, 24, 39]
#   Tile 208407: priority-weighted collision-free subset 2553/2865 targets (sep > 15.625 arcsec, sum priority+subpriority=256612.4)
#   Tile 208407: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=8685720482.00, assigned=1448, used_fibers=1448/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.17s
#   fba total time: 1.17s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208407.fits (1448 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1448 row(s) in 2 pixel file(s): [12, 24]
#   Update the MTL PRIORITY files in 0.03s
#
# =====================
# Tile 208408 (9.8630, 85.7472): loaded 25487 galaxies from 5 HEALPix file(s) pix=[4, 12, 23, 24, 39]
#   Tile 208408: priority-weighted collision-free subset 2571/2875 targets (sep > 15.625 arcsec, sum priority+subpriority=170285.6)
#   Tile 208408: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=8286662575.00, assigned=1471, used_fibers=1471/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 1.70s
#   fba total time: 1.70s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208408.fits (1471 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1471 row(s) in 2 pixel file(s): [12, 24]
#   Update the MTL PRIORITY files in 0.03s
#
# =====================
# Tile 208403 (6.9076, 84.1720): loaded 25589 galaxies from 5 HEALPix file(s) pix=[12, 24, 39, 40, 59]
#   Tile 208403: priority-weighted collision-free subset 2691/3069 targets (sep > 15.625 arcsec, sum priority+subpriority=98759.9)
#   Tile 208403: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=8996352154.00, assigned=1567, used_fibers=1567/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 2.03s
#   fba total time: 2.03s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208403.fits (1567 assignments); takes 0.02s
#   Updated PRIORITY on disk for 1567 row(s) in 2 pixel file(s): [24, 40]
#   Update the MTL PRIORITY files in 0.03s
#
# =====================
# Tile 208404 (27.2657, 84.1129): loaded 33391 galaxies from 4 HEALPix file(s) pix=[12, 24, 25, 41]
#   Tile 208404: priority-weighted collision-free subset 2098/2313 targets (sep > 15.625 arcsec, sum priority+subpriority=181578.2)
#   Tile 208404: 0 fiber-pair constraints, 0 target pairs
#   solve_tile_group finished: cost=5276697646.00, assigned=1347, used_fibers=1347/2184
#
# === Single Tile/Group Complete ===
# All constraints satisfied.
#   fba_onetile_decollided finished in 0.90s
#   fba total time: 0.90s
#   Wrote ./fba/output/decollided//11987tiles_0.0ra90.0_0.0dec90.0/seed100/fba_tile_208404.fits (1347 assignments); takes 0.01s
#   Updated PRIORITY on disk for 1347 row(s) in 4 pixel file(s): [12, 24, 25, 41]
#   Update the MTL PRIORITY files in 0.05s
#
# =====================
# pass 1 running time (s): 29.1
