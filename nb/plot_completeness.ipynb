# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append("/home/zjding/fiberassignment/algorithm")
from utils import get_spherearea

# %%
ifile = "./output/completeness_diffmagcut.txt"
rmagcut, targ_den, comp = np.loadtxt(ifile, unpack=True)

# %%
fig, ax1 = plt.subplots(dpi=120)
ax1.plot(rmagcut, comp, 's-', color='k')
ax1.set_xlabel("R apparent magnitude limit", fontsize=14)
ax1.set_ylabel(r"$G_{\mathrm{assign}}$ completeness", fontsize=14)

ax2 = ax1.twinx()
ax2.plot(rmagcut, targ_den, 'o--', color='C0')
ax2.set_ylabel(r"target density (deg$^{-2}$)", color="C0", fontsize=14)
ax1.set_title("one pass", fontsize=14)
ax1.grid()
plt.tight_layout()
